# %% [markdown]
# <a href="https://colab.research.google.com/github/CAIOZANETTI/IA_classificar_tabela/blob/main/AI_listaMaterial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Conceitos

# %% [markdown]
# Conceitos
#
# df_raw (dados brutos)
# df_feat (com features)
# df_final (pronto para modelar)

# %% [markdown]
# # Codigo

# %%
## @title 1. Carregar CSV
caminho = "/content/drive/MyDrive/00_notebooks/ia_lista_tubos/lista_tubos.csv"
df_raw = pd.read_csv(caminho, delimiter=';')
df_raw.head()
# Out:
#                                                 nome dimensao material  \
# 0     TUBO COM PONTA E BOLSA JUNTA ELÁSTICA JE2GS K7   DN1000       FD
# 1  TUBO COM PONTA E BOLSA JUNTA TRAVADA EXTERNA J...   DN1000       FD
# 2  CURVA 11°15' COM BOLSAS JUNTA TRAVADA EXTERNA JTE   DN1000       FD
# 3  CURVA 22°30' COM BOLSAS JUNTA TRAVADA EXTERNA JTE   DN1000       FD
# 4     CURVA 45° COM BOLSAS JUNTA TRAVADA EXTERNA JTE   DN1000       FD
#
#          qtd  unid        unit           total
# 0   1.512,00     m    3.381,18    5.112.344,16
# 1     497,00     m    5.268,35    2.618.367,96
# 2       5,00    UN   30.584,28      152.921,40
# 3      10,00    UN   34.594,62      345.946,20
# 4       8,00    UN   37.152,52      297.220,16

# %%
## @title 2. Verificar conteudo
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nome      567 non-null    object
#  1   dimensao  567 non-null    object
#  2   material  567 non-null    object
#  3    qtd      567 non-null    object
#  4   unid      567 non-null    object
#  5    unit     567 non-null    object
#  6    total    567 non-null    object
# dtypes: object(7)
# memory usage: 31.1+ KB

# %%
## @title 3. Engenharia

# 1. Extraindo features da coluna 'dimensao' (usando expressões regulares)
df_raw[['dn', 'comprimento']] = df_raw['dimensao'].str.extract(r'DN(\d+)(?:x([\d,]+)m)?')
